# %%
import pickle

with open("sample/train.txt", "rb") as f:
    data = pickle.load(f)

# Giả sử data = (out_seqs, labs)
out_seqs, labs = data

for i in range(len(out_seqs)):
    print(f"{i}: {out_seqs[i]} -> {labs[i]}")
# Out:
# 0: [1, 2] -> 3
# 1: [1] -> 2
# 2: [4] -> 5
# 3: [6] -> 7
# 4: [8, 9] -> 9
# 5: [8] -> 9
# 6: [10, 11, 11] -> 11
# 7: [10, 11] -> 11
# 8: [10] -> 11
# 9: [12] -> 13
# 10: [14] -> 14
# 11: [15, 16, 17] -> 18
# 12: [15, 16] -> 17
# 13: [15] -> 16
# 14: [19] -> 19
# 15: [20] -> 20
# 16: [21] -> 21
# 17: [22, 22, 23, 23, 23, 22, 23] -> 23
# 18: [22, 22, 23, 23, 23, 22] -> 23
# 19: [22, 22, 23, 23, 23] -> 22
# 20: [22, 22, 23, 23] -> 23
# 21: [22, 22, 23] -> 23
# 22: [22, 22] -> 23
# 23: [22] -> 22
# 24: [24, 25, 26] -> 27
# 25: [24, 25] -> 26
# 26: [24] -> 25
# 27: [1, 28, 3] -> 2
# 28: [1, 28] -> 3
# 29: [1] -> 28
# 30: [29] -> 30
# 31: [31, 32, 31, 31, 31] -> 31
# 32: [31, 32, 31, 31] -> 31
# 33: [31, 32, 31] -> 31
# 34: [31, 32] -> 31
# 35: [31] -> 32
# 36: [33, 33] -> 33
# 37: [33] -> 33
# 38: [34, 34, 34, 34, 34] -> 34
# 39: [34, 34, 34, 34] -> 34
# 40: [34, 34, 34] -> 34
# 41: [34, 34] -> 34
# 42: [34] -> 34
# 43: [12, 13, 12, 13, 35, 35, 12, 13] -> 12
# ...

# %%
# !pip install kagglehub
import kagglehub

# Download latest version
path = kagglehub.dataset_download("chadgostopp/recsys-challenge-2015")

print("Path to dataset files:", path)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 2.0 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# ...
# 100%|██████████| 841M/841M [01:13<00:00, 12.0MB/s]
# Extracting model files...
# Path to dataset files: /Users/admin/.cache/kagglehub/datasets/chadgostopp/recsys-challenge-2015/versions/1

# %%
mkdir -p datasets/recsys15

# %%
cp -r ~/.cache/kagglehub/datasets/chadgostopp/recsys-challenge-2015/versions/1 ./datasets/recsys15
